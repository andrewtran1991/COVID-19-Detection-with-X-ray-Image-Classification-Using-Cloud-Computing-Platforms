# %%
def resize(path):
    dirs = os.listdir(path)
    for item in dirs:
        if os.path.isfile(path+item):
            im = Image.open(path+item)
            f, e = os.path.splitext(path+item)
            imResize = im.resize((200,200), Image.ANTIALIAS)
            imResize = imResize.convert('RGB')
            imResize.save(f+".jpg", 'JPEG', quality=90)
            if (e !=".jpg"):
              os.remove(path+item)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from PIL import Image
import os, sys

path_normal = '/dbfs/FileStore/tables/X-Ray Image DataSet/normal/'
path_covid = '/dbfs/FileStore/tables/X-Ray Image DataSet/covid/'
path_viral = '/dbfs/FileStore/tables/X-Ray Image DataSet/viral/'

resize(path_normal)
resize(path_covid)
resize(path_viral)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import tensorflow as tf
import pyspark.sql.functions as f
import sparkdl as dl
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#dfDjokovic = spark.read.format("image").load('./FileStore/tables/5').withColumn('label', f.lit(0))
#dfFederer = spark.read.format("image").load('./FileStore/tables/X-Ray Image DataSet/covid').withColumn('label', f.lit(1))
from sparkdl.image import imageIO
normal_df= imageIO.readImagesWithCustomFn('./FileStore/tables/X-Ray Image DataSet/normal', decode_f=imageIO.PIL_decode).withColumn('label', f.lit(0))
covid_df= imageIO.readImagesWithCustomFn('./FileStore/tables/X-Ray Image DataSet/covid', decode_f=imageIO.PIL_decode).withColumn('label', f.lit(1))
display(normal_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>image</th><th>label</th></tr></thead><tbody><tr><td>List(dbfs:/FileStore/tables/X-Ray Image DataSet/normal/00001385_000.jpg, 200, 200, 3, 16, Binary image data placeholder. Access the image data field directly to view raw binary data., ...)</td><td>0</td></tr><tr><td>List(dbfs:/FileStore/tables/X-Ray Image DataSet/normal/00001385_003.jpg, 200, 200, 3, 16, Binary image data placeholder. Access the image data field directly to view raw binary data., ...)</td><td>0</td></tr><tr><td>List(dbfs:/FileStore/tables/X-Ray Image DataSet/normal/00001389_001.jpg, 200, 200, 3, 16, Binary image data placeholder. Access the image data field directly to view raw binary data., ...)</td><td>0</td></tr><tr><td>List(dbfs:/FileStore/tables/X-Ray Image DataSet/normal/00001389_002.jpg, 200, 200, 3, 16, Binary image data placeholder. Access the image data field directly to view raw binary data., ...)</td><td>0</td></tr><tr><td>List(dbfs:/FileStore/tables/X-Ray Image DataSet/normal/00001389_003.jpg, 200, 200, 3, 16, Binary image data placeholder. Access the image data field directly to view raw binary data., ...)</td><td>0</td></tr><tr><td>List(dbfs:/FileStore/tables/X-Ray Image DataSet/normal/00001395_009.jpg, 200, 200, 3, 16, Binary image data placeholder. Access the image data field directly to view raw binary data., ...)</td><td>0</td></tr><tr><td>List(dbfs:/FileStore/tables/X-Ray Image DataSet/normal/00001401_001.jpg, 200, 200, 3, 16, Binary image data placeholder. Access the image data field directly to view raw binary data., ...)</td><td>0</td></tr><tr><td>List(dbfs:/FileStore/tables/X-Ray Image DataSet/normal/00001403_002.jpg, 200, 200, 3, 16, Binary image data placeholder. Access the image data field directly to view raw binary data., ...)</td><td>0</td></tr><tr><td>List(dbfs:/FileStore/tables/X-Ray Image DataSet/normal/00001426_000.jpg, 200, 200, 3, 16, Binary image data placeholder. Access the image data field directly to view raw binary data., ...)</td><td>0</td></tr><tr><td>List(dbfs:/FileStore/tables/X-Ray Image DataSet/normal/00001433_002.jpg, 200, 200, 3, 16, Binary image data placeholder. Access the image data field directly to view raw binary data., ...)</td><td>0</td></tr><tr><td>List(dbfs:/FileStore/tables/X-Ray Image DataSet/normal/00001445_000.jpg, 200, 200, 3, 16, Binary image data placeholder. Access the image data field directly to view raw binary data., ...)</td><td>0</td></tr><tr><td>List(dbfs:/FileStore/tables/X-Ray Image DataSet/normal/00001452_002.jpg, 200, 200, 3, 16, Binary image data placeholder. Access the image data field directly to view raw binary data., ...)</td><td>0</td></tr><tr><td>List(dbfs:/FileStore/tables/X-Ray Image DataSet/normal/00001460_004.jpg, 200, 200, 3, 16, Binary image data placeholder. Access the image data field directly to view raw binary data., ...)</td><td>0</td></tr><tr><td>List(dbfs:/FileStore/tables/X-Ray Image DataSet/normal/00001464_000.jpg, 200, 200, 3, 16, Binary image data placeholder. Access the image data field directly to view raw binary data., ...)</td><td>0</td></tr><tr><td>List(dbfs:/FileStore/tables/X-Ray Image DataSet/normal/00001470_003.jpg, 200, 200, 3, 16, Binary image data placeholder. Access the image data field directly to view raw binary data., ...)</td><td>0</td></tr><tr><td>List(dbfs:/FileStore/tables/X-Ray Image DataSet/normal/00001471_001.jpg, 200, 200, 3, 16, Binary image data placeholder. Access the image data field directly to view raw binary data., ...)</td><td>0</td></tr><tr><td>List(dbfs:/FileStore/tables/X-Ray Image DataSet/normal/00001483_017.jpg, 200, 200, 3, 16, Binary image data placeholder. Access the image data field directly to view raw binary data., ...)</td><td>0</td></tr><tr><td>List(dbfs:/FileStore/tables/X-Ray Image DataSet/normal/00001483_021.jpg, 200, 200, 3, 16, Binary image data placeholder. Access the image data field directly ...

# %%
normal_train, normal_test= normal_df.randomSplit([0.8,0.2])  # use larger training sets (e.g. [0.6, 0.4] for non-community edition clusters)
covid_train, covid_test= covid_df.randomSplit([0.8,0.2])     # use larger training sets (e.g. [0.6, 0.4] for non-community edition clusters)
train_df = normal_train.unionAll(covid_train)
test_df = normal_test.unionAll(covid_test)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(test_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>image</th><th>label</th></tr></thead><tbody><tr><td>List(dbfs:/FileStore/tables/X-Ray Image DataSet/normal/00001445_000.jpg, 200, 200, 3, 16, Binary image data placeholder. Access the image data field directly to view raw binary data., ...)</td><td>0</td></tr><tr><td>List(dbfs:/FileStore/tables/X-Ray Image DataSet/normal/00001569_003.jpg, 200, 200, 3, 16, Binary image data placeholder. Access the image data field directly to view raw binary data., ...)</td><td>0</td></tr><tr><td>List(dbfs:/FileStore/tables/X-Ray Image DataSet/normal/00001573_000.jpg, 200, 200, 3, 16, Binary image data placeholder. Access the image data field directly to view raw binary data., ...)</td><td>0</td></tr><tr><td>List(dbfs:/FileStore/tables/X-Ray Image DataSet/normal/00001595_002.jpg, 200, 200, 3, 16, Binary image data placeholder. Access the image data field directly to view raw binary data., ...)</td><td>0</td></tr><tr><td>List(dbfs:/FileStore/tables/X-Ray Image DataSet/normal/00001616_008.jpg, 200, 200, 3, 16, Binary image data placeholder. Access the image data field directly to view raw binary data., ...)</td><td>0</td></tr><tr><td>List(dbfs:/FileStore/tables/X-Ray Image DataSet/normal/00001620_003.jpg, 200, 200, 3, 16, Binary image data placeholder. Access the image data field directly to view raw binary data., ...)</td><td>0</td></tr><tr><td>List(dbfs:/FileStore/tables/X-Ray Image DataSet/normal/00001638_000.jpg, 200, 200, 3, 16, Binary image data placeholder. Access the image data field directly to view raw binary data., ...)</td><td>0</td></tr><tr><td>List(dbfs:/FileStore/tables/X-Ray Image DataSet/normal/00001371_002.jpg, 200, 200, 3, 16, Binary image data placeholder. Access the image data field directly to view raw binary data., ...)</td><td>0</td></tr><tr><td>List(dbfs:/FileStore/tables/X-Ray Image DataSet/covid/1_s2_0_S1684118220300682_main_pdf_002_a2.jpg, 200, 200, 3, 16, Binary image data placeholder. Access the image data field directly to view raw binary data., ...)</td><td>1</td></tr><tr><td>List(dbfs:/FileStore/tables/X-Ray Image DataSet/covid/5CBC2E94_D358_401E_8928_965CCD965C5C.jpg, 200, 200, 3, 16, Binary image data placeholder. Access the image data field directly to view raw binary data., ...)</td><td>1</td></tr><tr><td>List(dbfs:/FileStore/tables/X-Ray Image DataSet/covid/6C94A287_C059_46A0_8600_AFB95F4727B7.jpg, 200, 200, 3, 16, Binary image data placeholder. Access the image data field directly to view raw binary data., ...)</td><td>1</td></tr><tr><td>List(dbfs:/FileStore/tables/X-Ray Image DataSet/covid/6CB4EFC6_68FA_4CD5_940C_BEFA8DAFE9A7.jpg, 200, 200, 3, 16, Binary image data placeholder. Access the image data field directly to view raw binary data., ...)</td><td>1</td></tr><tr><td>List(dbfs:/FileStore/tables/X-Ray Image DataSet/covid/F63AB6CE_1968_4154_A70F_913AF154F53D.jpg, 200, 200, 3, 16, Binary image data placeholder. Access the image data field directly to view raw binary data., ...)</td><td>1</td></tr><tr><td>List(dbfs:/FileStore/tables/X-Ray Image DataSet/covid/FE9F9A5D_2830_46F9_851B_1FF4534959BE.jpg, 200, 200, 3, 16, Binary image data placeholder. Access the image data field directly to view raw binary data., ...)</td><td>1</td></tr><tr><td>List(dbfs:/FileStore/tables/X-Ray Image DataSet/covid/all14238_fig_0002_m_e.jpg, 200, 200, 3, 16, Binary image data placeholder. Access the image data field directly to view raw binary data., ...)</td><td>1</td></tr><tr><td>List(dbfs:/FileStore/tables/X-Ray Image DataSet/covid/1F6343EE_AFEC_4B7D_97F5_62797EE18767.jpg, 200, 200, 3, 16, Binary image data placeholder. Access the image data field directly to view raw binary data., ...)</td><td>1</td></tr><tr><td>List(dbfs:/FileStore/tables/X-Ray Image DataSet/covid/covid_19_pneumonia_19.jpg, 200, 200, 3, 16, Binary image data placeholder. Access the image data field directly to view raw binary data., ...)</td ...

# %%
from pyspark.ml.classification import LogisticRegression
from pyspark.ml import Pipeline
from sparkdl import DeepImageFeaturizer 

featurizer = DeepImageFeaturizer(inputCol="image", outputCol="features", modelName="InceptionV3")
lr = LogisticRegression(maxIter=20, regParam=0.05, elasticNetParam=0.3, labelCol="label")
p = Pipeline(stages=[featurizer, lr])

p_model = p.fit(train_df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.ml.evaluation import MulticlassClassificationEvaluator

tested_df = p_model.transform(test_df)
evaluator = MulticlassClassificationEvaluator(metricName="accuracy")
print("Test set accuracy = " + str(evaluator.evaluate(tested_df.select("prediction", "label"))))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Test set accuracy = 0.967741935483871
# </div>

# %%
from pyspark.sql.types import DoubleType
from pyspark.sql.functions import expr
def _p1(v):
  return float(v.array[1])
p1 = udf(_p1, DoubleType())

df = tested_df.withColumn("p_1", p1(tested_df.probability))
wrong_df = df.orderBy(expr("abs(p_1 - label)"), ascending=False)
display(wrong_df.select("image.origin", "p_1", "label").limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>origin</th><th>p_1</th><th>label</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/X-Ray Image DataSet/normal/00001308_002.jpg</td><td>0.673272975595755</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/X-Ray Image DataSet/normal/00001616_009.jpg</td><td>0.6680881720498342</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/X-Ray Image DataSet/normal/00001569_003.jpg</td><td>0.5135371201680996</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/X-Ray Image DataSet/normal/00001526_002.jpg</td><td>0.4432231563773966</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/X-Ray Image DataSet/covid/D7AF463C_2369_492D_908D_BE1911CCD74C.jpg</td><td>0.5625953936042507</td><td>1</td></tr><tr><td>dbfs:/FileStore/tables/X-Ray Image DataSet/normal/00001684_021.jpg</td><td>0.4168735075008516</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/X-Ray Image DataSet/normal/00001682_001.jpg</td><td>0.34993053504481136</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/X-Ray Image DataSet/normal/00001620_003.jpg</td><td>0.30437317554995647</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/X-Ray Image DataSet/normal/00001395_009.jpg</td><td>0.2782969408666</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/X-Ray Image DataSet/covid/covid_19_rapidly_progressive_acute_respiratory_distress_syndrome_ards_admission.jpg</td><td>0.7830611685547768</td><td>1</td></tr></tbody></table></div>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
import matplotlib.pyplot as plt
import numpy as np
import itertools
def plot_confusion_matrix(cm, classes,normalize=False,title='Confusion matrix',cmap=plt.cm.GnBu):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from sklearn.metrics import confusion_matrix
y_true = tested_df.select("label")
y_true = y_true.toPandas()
y_pred = tested_df.select("prediction")
y_pred = y_pred.toPandas()
cnf_matrix = confusion_matrix(y_true, y_pred,labels=range(2))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(plot_confusion_matrix(cnf_matrix, classes=["normal","covid"]))

# %%
from sklearn.metrics import classification_report
target_names = ["Class {}".format(i) for i in ["normal","covid"]]
print(classification_report(y_true, y_pred, target_names = target_names))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">              precision    recall  f1-score   support
#
# Class normal       1.00      0.93      0.97        15
#  Class covid       0.94      1.00      0.97        16
#
#    micro avg       0.97      0.97      0.97        31
#    macro avg       0.97      0.97      0.97        31
# weighted avg       0.97      0.97      0.97        31
#
# </div>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
